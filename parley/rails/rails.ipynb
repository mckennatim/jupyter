# %% [markdown]
# # back porch rails

# %% [markdown]
# ## azek classic composite rails
# * [azek video](https://www.youtube.com/watch?v=iXg88fS0_Eg)
# * [doctor decks](https://www.youtube.com/watch?v=FJOHHdD0-6o)
#
# ### actual rail sizes
# - 6' = 68.4"
# - 8' = 92"

# %%
fsize = 72.375 - 3/4 -3.5
print(fsize)
# Out:
# 68.125

# %% [markdown]
# ### pricing
#
# #### [white only CT](https://www.ringsend.com/timbertechr-classic-composite-series-universal-rail-kit-matte-white-8-ft)
# - 6' w balusters $155

# %% [markdown]
# ### quotes
# - Richard rrobicheau@national-lumber.com
# - Courtney courtney@ryanbp.com
# - braintree_all@lansingbp.com
#
#
# https://medium.com/mlearning-ai/set-up-remote-jupyter-lab-notebook-server-for-remote-browser-access-2cef464f203e
#
# https://decovar.dev/blog/2020/05/27/jupyter-notebook-nginx/

# %%
# %%js
# alert("hello world");

# %% [markdown]
# ![image-f190362ae40eda52eb4059a3a587e7a2f499bc4b52a7dd65cc1b34076f4b165a-V.jpg](attachment:aa42006f-460d-42c0-9aa1-181ae413aa1b.jpg)
